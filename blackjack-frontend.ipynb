# %%
# !python --version
# !pip install --upgrade pip
# !pip install pika
# !git clone https://github.com/elephantrobotics/pymycobot pymycobot_src
# !mv pymycobot_src/pymycobot .
# !pip install pyserial
# !pip install -q 'ultralytics' onnx
# Out:
# Python 3.9.18
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/mwright/.local/lib/python3.10/site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/47/6a/453160888fab7c6a432a6e25f8afe6256d0d9f2cbd25971021da6491d899/pip-23.3.1-py3-none-any.whl.metadata
#   Downloading pip-23.3.1-py3-none-any.whl.metadata (3.5 kB)
# Downloading pip-23.3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-23.3.1
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pika in /home/mwright/.local/lib/python3.10/site-packages (1.3.2)
# Cloning into 'pymycobot_src'...
# remote: Enumerating objects: 2325, done.
# remote: Counting objects: 100% (258/258), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 2325 (delta 223), reused 201 (delta 201), pack-reused 2067
# Receiving objects: 100% (2325/2325), 3.07 MiB | 16.48 MiB/s, done.
# Resolving deltas: 100% (1666/1666), done.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyserial
#   Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: pyserial
# Successfully installed pyserial-3.5

# %%
CONFIDENCE_NEEDED = .4
LABEL_X_DIST = 146
LABEL_Y_DIST = 230
LABEL_DIST_VARIANCE = .20
ROBOT_ATTACHED = False

# %%
import json
import serial
import serial.tools.list_ports
import time

from pymycobot.mycobot import MyCobot

def setup_robot():
    mc = MyCobot("/dev/ttyACM0", debug=False)
    mc.send_angles([0,0,0,0,0,0], 100)
    return mc

def motion_hit(sp):
    print("HIT ME!")
    mc.send_angles([0,0,90,0,90,135], sp)
    time.sleep(3)
    mc.send_angles([0,0,90,0,90,0], sp)
    time.sleep(3)
    mc.send_angles([0,0,90,0,90,135], sp)
    
def motion_hold(sp):
    print("I'm good. HOLD!")
    mc.send_angles([0,0,90,0,0,135], sp)
    time.sleep(3)
    mc.send_angles([0,0,90,0,0,0], sp)
    time.sleep(3)
    mc.send_angles([0,0,90,0,0,135], sp)

def motion_bust(sp):
    print("Awe maan!  Let's go to the slots")
    mc.send_angles([0,45,90,0,0,135], sp)
    time.sleep(3)
    mc.send_angles([0,0,90,0,0,0], sp)
    time.sleep(3)
    mc.send_angles([0,0,90,-35,90,135], sp)
    
def motion_ready(sp):
    print("Let's Play some Blackjack!")
    mc.send_angles([0,0,0,0,0,0], sp)

# %%
def score_hand(hand):
    score = 0
    aceCount = 0
    for card in hand:
        print(card[0])
        if card[0] in {'K','Q','J'}:
            score += 10
        elif card[0] == 'A':
            aceCount+=1
        elif card[0] == '1' and card[1] == '0':
            score += 10
        else:
            score += int(card[0])
    print("Ace count: " + str(aceCount))
    if aceCount == 2 and score == 0:
        #only have 2 aces, count 1 as value 11 and the other as value 1
        score = 12
    elif aceCount == 2 and score > 9:
        #can't count as 12, need to score both as value 1
        score += 2
    elif aceCount == 2 and score <= 9:
        #add 12, one is value 11, one is value 1
        score += 12
    elif aceCount == 1 and score == 0:
        #only have one ace
        score = 11
    elif aceCount == 1 and score > 10:
        #counting as 11 would bust
        score += 1
    elif aceCount == 1 and score <= 10:
        #count as 11
        score += 11
    elif aceCount > 2:
        #applying simple rule here :-)
        score += aceCount

    return score

# %%
global myHand
myHand = {}
global prev_card
prev_card = ''

def add_keys_nested_dict(d, keys):
    for key in keys:
        if key not in d:
            d[key] = {}
        d = d[key]
    d.setdefault(keys[-1], 1)
    
def check_opposite_label(x, y):
    for card, details in myHand.items():
        print(details)
        if len(details) > 0:
            if abs(details['x'] - x) <= (LABEL_X_DIST + LABEL_DIST_VARIANCE*LABEL_X_DIST) and abs(details['y'] - y) <= (LABEL_Y_DIST + LABEL_DIST_VARIANCE*LABEL_Y_DIST):
                print("second label from captured card: " + card)
                return card
    return ''

prev_score=0

def card_inference(msg, prev_card):
  global myHand
  global prev_score
  hand_score = 0
  print(" [x] Received " + str(msg))
  cardSeen = json.loads(msg)
  card = cardSeen["class"]

  if float(cardSeen["score"])>CONFIDENCE_NEEDED and card not in myHand.keys():
        if card == "NONE":
            myHand = {}
            motion_ready(80)
        else:
            #check if we have another card recorded at roughly same location, replace if confidence higher
            overlapping_card = check_opposite_label(float(cardSeen['x1']), float(cardSeen['y1']))
            if len(overlapping_card) > 0 and myHand[overlapping_card]['confidence'] < float(cardSeen["score"]):
                del myHand[overlapping_card]
                myHand[card] = {}
                myHand[card]['x'] = float(cardSeen['x1'])
                myHand[card]['y'] = float(cardSeen['y1'])
                myHand[card]['confidence'] = float(cardSeen["score"])
            if len(overlapping_card) == 0:
                myHand[card] = {}
                myHand[card]['x'] = float(cardSeen['x1'])
                myHand[card]['y'] = float(cardSeen['y1'])
                myHand[card]['confidence'] = float(cardSeen["score"])
                
            hand_score = score_hand(myHand)
            
            if hand_score != prev_score:
                prev_score = hand_score
                if hand_score > 21:
                    motion_bust(50)
                elif hand_score > 15:
                    motion_hold(50)
                else: 
                    motion_hit(50)
        print('My Hand:' + str(myHand) + ', score: ' + str(hand_score))
  return card

# %%
import pika, os

rabbitmq_hostname = os.environ.get(
    'AMQP_HOSTNAME', 'localhost'
)
rabbitmq_port = os.environ.get(
    'AMQP_PORT', '5672'
)
rabbitmq_user = os.environ.get(
    'AMQP_USER', 'user'
)
rabbitmq_password = os.environ.get(
    'AMQP_PASSWORD', 'guest'
)

print (rabbitmq_user, rabbitmq_password)
credentials = pika.PlainCredentials(rabbitmq_user, rabbitmq_password)
parameters = pika.ConnectionParameters(rabbitmq_hostname,
                                       rabbitmq_port,
                                       '/',
                                       credentials)

connection = pika.BlockingConnection(parameters)
channel = connection.channel() # start a channel

# Declare a Stream, named test_stream
channel.queue_declare(
  queue='inferencing_stream',
      durable=True,
  arguments={"x-queue-type": "stream", "x-max-age": "1m"}
)
# Out:
# user guest
# <METHOD(['channel_number=1', 'frame_type=1', "method=<Queue.DeclareOk(['consumer_count=0', 'message_count=1496', 'queue=inferencing_stream'])>"])>

# %%
def ack_message(channel, delivery_tag):
    """Note that `channel` must be the same pika channel instance via which
    the message being ACKed was retrieved (AMQP protocol constraint).
    """
    if channel.is_open:
        channel.basic_ack(delivery_tag)

# create a function which is called on incoming messages
def hande_inference_message(ch, method, properties, body):
  #print(body)
  global prev_card
  prev_card = card_inference(body, prev_card)
  ack_message(ch,method.delivery_tag)

# Set the consumer QoS prefetch
channel.basic_qos(
  prefetch_count=100
)

# Consume messages published to the stream
channel.basic_consume(
  'inferencing_stream',
  hande_inference_message,
  arguments={"x-stream-offset": "last"}
)
# Out:
# 'ctag1.6e7b90a2049f4376af7025c4a33c92fc'

# %%
mc = setup_robot()

# start consuming (blocks)
channel.start_consuming()

dealMore=True

connection.close()
print(myHand)
# Out:
#  [x] Received b'{"class": "NONE", "score": "1", "x1": "0", "y1": "0" }'
# Let's Play some Blackjack!
# My Hand:{}, score: 0
#  [x] Received b'{"class": "NONE", "score": "1", "x1": "0", "y1": "0" }'
# Let's Play some Blackjack!
# My Hand:{}, score: 0
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
# 9
# Ace count: 0
# HIT ME!
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "9D", "score": "0.77685546875", "x1": "348.0", "y1": "502.0" }'
#  [x] Received b'{"class": "10H", "score": "0.338134765625", "x1": "271.0", "y1": "336.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "10H", "score": "0.5390625", "x1": "280.0", "y1": "269.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.328369140625", "x1": "354.0", "y1": "445.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "9D", "score": "0.78515625", "x1": "354.0", "y1": "534.0" }'
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10H", "score": "0.640625", "x1": "339.0", "y1": "404.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "10C", "score": "0.3642578125", "x1": "373.0", "y1": "457.0" }'
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "QH", "score": "0.423828125", "x1": "370.0", "y1": "467.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.398681640625", "x1": "381.0", "y1": "476.0" }'
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9H", "score": "0.439208984375", "x1": "383.0", "y1": "440.0" }'
# {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}
# second label from captured card: 9D
# 9
# Ace count: 0
# My Hand:{'9D': {'x': 348.0, 'y': 502.0, 'confidence': 0.77685546875}}, score: 9
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "9S", "score": "0.3291015625", "x1": "390.0", "y1": "508.0" }'
#  [x] Received b'{"class": "NONE", "score": "1", "x1": "0", "y1": "0" }'
# Let's Play some Blackjack!
# My Hand:{}, score: 0
